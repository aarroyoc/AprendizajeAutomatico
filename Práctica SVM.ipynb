# %% [markdown]
# # Ejercicio 1

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
plt.plot([1,2,2,1], [1,1,2,3], 'ro')
plt.plot([-1,0,-1],[1,2,3],"go")
plt.axvline(x=0.5)
X = np.linspace(-1,2,10)
Y = -0.5+X*6.42
plt.plot(X,Y,"y")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Tanto el perceptrón simple como el SVM tienen una tasa de aciertos del 100%

# %% [markdown]
# # Ejercicio 2

# %% [markdown]
# PolyKernel(1): 98,36 %
#
# PolyKernel(2): 100%
#
# Puk(omega=1,sigma=1): 100%
#
# NormalizedPolyKernel(2): 98,36%
#
# NormalizedPolyKernel(3): 98,36%
#
# NormalizedPolyKernel(4): 98,36%
#
# NormalizedPolyKernel(5): 98,36%
#
# RBFKernel(gamma=0.01): 32,78%
#
# RBFKernel(gamma=0.001): 32,78%
#
# RBFKernel(gamma=0.1): 100%
